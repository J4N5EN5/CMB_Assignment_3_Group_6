# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install sty
# Out:
# Collecting sty
#   Downloading sty-1.0.4-py3-none-any.whl (11 kB)
# Installing collected packages: sty
# Successfully installed sty-1.0.4

# %%
import os
import sys
import json
import bz2
import urllib.request

from math import sin, cos, sqrt, atan2, radians
from sty import fg, bg, ef, rs


def distance(x,y):
  R = 6373.0

  lat1 = radians(x[0])
  lon1 = radians(x[1])
  lat2 = radians(y[0])
  lon2 = radians(y[1])

  dlon = lon2 - lon1
  dlat = lat2 - lat1

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c

  return distance

def download(ripedir,filename):
  pprint("Downloading meta-latest as: "+filename)
  urllib.request.urlretrieve("https://ftp.ripe.net/ripe/atlas/probes/archive/meta-latest", ripedir+filename)

def unzip(ripedir,filename):
  pprint("Unziping as meta-latest.json")
  zipfile = bz2.BZ2File(ripedir+filename)
  data = zipfile.read()
  f = open("meta-latest.json", 'wb')
  f.write(data)
  f.close()
  pprint("Done!")

def pprint(s, level=0):
  if level == 0:
    print("["+fg.green+"INFO"+fg.rs+"] "+s)
  elif level == 1:
    print("["+fg.yellow+"WARN"+fg.rs+"] "+s)
  elif level == 2:
    print("["+fg.red+"ERROR"+fg.rs+"] "+s)


filename = ""
ripedir = "ripe/"

if not os.path.exists(ripedir):
  pprint("Please create "+ripedir+" folder first!", level=2)
  sys.exit(-1)


page = urllib.request.urlopen('https://ftp.ripe.net/ripe/atlas/probes/archive/')
for line in page.read().decode().split("\n"):
  if "meta-latest" in line:
    a = list(filter(lambda a: a != "", line.split(" ")))
    filename = a[2]+"-"+a[3]+".bz2"

exist = os.path.exists(ripedir+filename)
if not exist:
  pprint("New meta-latest exists!")
  download(ripedir,filename)
  unzip(ripedir,filename)
else:
  pprint(filename+" found!")
  pprint("Skipping download and unzip...")

if not os.path.exists("meta-latest.json"):
  if exist:
    unzip(ripedir,filename)
  else:
    pprint("Should not happen!",2)
    sys.exit(-1)

f = open("meta-latest.json")
data = json.loads(f.read())
f.close()
pprint("Reade File!")

starlink, home, lte = False, False, False
e_wlan = None
e_lte = None
for e in data["objects"]:
  if e["status_name"] == "Connected":
    
    if "lte" in e["tags"] and not lte:
      print("----------lte----------")
      print(e)
      print("----------lte----------")
      lte = True
      e_lte = e
    
    if "wlan" in e["tags"] and not home:
      print("----------wlan----------")
      print(e)
      print("----------wlan----------")
      home = True
      e_wlan = e

    if e["asn_v4"] == 14593 and not starlink:
      print("----------Starlink----------")
      print(e)
      print("----------Starlink----------")
      starlink = True
  
  if starlink and lte and home:
    break

distance = distance((e_lte["latitude"],e_lte["longitude"]),(e_wlan["latitude"],e_wlan["longitude"]))

print(f"Distance between lte and wlan: {distance}km")
# Out:
# [INFO] New meta-latest exists!
# [INFO] Downloading meta-latest as: 29-Jan-2023-05:25.bz2
# [INFO] Unziping as meta-latest.json
# [INFO] Done!
# [INFO] Reade File!
# ----------lte----------
# {'id': 1000234, 'address_v4': None, 'address_v6': '2a01:598:b9a3:9b97:dea6:32ff:fe23:6be1', 'asn_v4': None, 'asn_v6': 3320, 'prefix_v4': None, 'prefix_v6': '2a01:598::/29', 'is_anchor': False, 'is_public': True, 'status': 1, 'status_since': 1674648077, 'first_connected': 1582125371, 'total_uptime': 92416457, 'tags': ['telekom', 'system-ipv4-stable-1d', 'system-ipv6-stable-1d', 'system-ipv6-stable-90d', 'system-ipv4-stable-90d', 'system-ipv6-stable-30d', 'system-ipv4-stable-30d', 'system-resolves-aaaa-correctly', 'system-resolves-a-correctly', 'system-ipv6-works', 'system-ipv4-works', 'system-ipv4-rfc1918', '5g', 'raspberry-pi', 'ipv6-only', '4g', 'nat64', 'mobile', 'lte', 'dtag', '464xlat', 'native-ipv6', 'ipv6', 'system-ipv6-capable', 'system-software'], 'country_code': 'DE', 'latitude': 48.0995, 'longitude': 11.5285, 'day': '20230128', 'probe': 'https://atlas.ripe.net/api/v2/probes/1000234/', 'status_name': 'Connected'}
# ----------lte----------
# ----------Starlink----------
# {'id': 1001040, 'address_v4': '98.97.40.137', 'address_v6': None, 'asn_v4': 14593, 'asn_v6': None, 'prefix_v4': '98.97.40.0/21', 'prefix_v6': None, 'is_anchor': False, 'is_public': True, 'status': 1, 'status_since': 1674807038, 'first_connected': 1599994326, 'total_uptime': 24835856, 'tags': ['system-ipv4-stable-1d', 'system-resolves-aaaa-correctly', 'system-resolves-a-correctly', 'system-ipv4-works', 'system-ipv4-capable', 'system-ipv4-rfc1918', 'system-software'], 'country_code': 'US', 'latitude': 45.5575, 'longitude': -122.8705, 'day': '20230128', 'probe': 'https://atlas.ripe.net/api/v2/probes/1001040/', 'status_name': 'Connected'}
# ----------Starlink----------
# ----------wlan----------
# {'id': 18169, 'address_v4': '146.231.130.254', 'address_v6': '2001:43f8:750:1100:c24a:ff:fecc:75c2', 'asn_v4': 37520, 'asn_v6': 37520, 'prefix_v4': '146.231.0.0/16', 'prefix_v6': '2001:43f8:750::/44', 'is_anchor': False, 'is_public': True, 'status': 1, 'status_since': 1669381822, 'first_connected': 1411395280, 'total_uptime': 260661858, 'tags': ['system-ipv4-stable-1d', 'system-resolves-aaaa-correctly', 'system-resolves-a-correctly', 'system-ipv6-works', 'system-ipv4-works', 'system-ipv4-stable-90d', 'system-ipv4-stable-30d', 'fibre', 'datacentre', 'academic', 'no-nat', 'multihomed', 'system-v3', 'wlan', 'system-ipv4-capable', 'system-ipv6-capable', 'eduroam'], 'country_code': 'ZA', 'latitude': -33.3085, 'longitude': 26.5205, 'day': '20230128', 'probe': 'https://atlas.ripe.net/api/v2/probes/18169/', 'status_name': 'Connected'}
# ----------wlan----------
# Distance between lte and wlan: 9177.274852744635km
